# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

df = pd.read_csv('1TessData250523.csv')
dFFinal2505 = pd.DataFrame(df)
dFFinal2505
# Out:
#      pl_rade  pl_radj   pl_bmasse  pl_bmassj  st_teff  pl_eqt    Pl_eh_vol  \
# 0      2.610    0.233    22.70000    0.07142   4640.0     422    17.779581
# 1      2.130    0.190     3.34000    0.01051   3556.0     693     9.663597
# 2      1.264    0.113     1.86000    0.00585   3347.0     773     2.019488
# 3      1.217    0.109     1.84000    0.00579   3505.0     525     1.802485
# 4      0.718    0.064     0.54600    0.00172   3522.0    1745     0.370146
# ..       ...      ...         ...        ...      ...     ...          ...
# 207   11.994    1.070   301.93850    0.95000   6261.0    1397  1725.409296
# 208   13.126    1.171   211.99261    0.66700   5570.0    1192  2261.503164
# 209    9.550    0.852    55.30242    0.17400   5710.0    1526   870.983875
# 210    2.765    0.247     9.10000    0.02863   4435.0     941    21.139047
# 211   10.400    0.928  4386.05400   13.80000   4710.0     163  1124.864000
#
#      Pl_J_vol  dens_pl_ert   dens_pl_jup
# ...

# %%
dataForstudy02_06=dFFinal2505[["pl_rade","pl_bmasse","st_teff","pl_eqt","Pl_eh_vol","dens_pl_ert"]]
dataForstudy02_06.to_csv('RealTessDataUse.csv')

# %%
import matplotlib.pyplot as plt

# Obtener las densidades de los exoplanetas y la densidad de la Tierra
densidades_exoplanetas = dFFinal2505['dens_pl_ert']  # Reemplaza "df['densidades']" con la columna que contiene las densidades de tus exoplanetas
densidad_tierra = 1  # Densidad de la Tierra

# Crear una lista de valores de 0 para el eje y
densidad_tierra_comparativa = [densidad_tierra] * len(densidades_exoplanetas)

# Crear una lista de tamaños para las burbujas
sizes = [100] * len(densidades_exoplanetas)  # Puedes ajustar el tamaño de las burbujas según tus preferencias

# Crear una lista de colores para las burbujas
colors = ['blue'] * len(densidades_exoplanetas)  # Puedes ajustar el color de las burbujas según tus preferencias

# Graficar las densidades comparativas en un gráfico de burbujas
plt.scatter(range(len(densidades_exoplanetas)), densidad_tierra_comparativa, s=sizes, c='gold', alpha=0.5, label='Earth density')
plt.scatter(range(len(densidades_exoplanetas)), densidades_exoplanetas, s=sizes, c='mediumorchid', alpha=0.5, label='Exoplanet density')

# Etiquetas y título del gráfico
plt.xlabel('Exoplanet Index')
plt.ylabel('Density times earth')


# Ajustar los límites de los ejes para el acercamiento
plt.xlim(-5, len(densidades_exoplanetas) + 5)  # Ajusta los valores -5 y +5 según la zona que deseas mostrar en el eje x
plt.ylim(-0.5, 2)  # Ajusta los valores -0.5 y 2 según la zona que deseas mostrar en el eje y

# Leyenda
plt.legend()
plt.savefig('grafica_densidades.png')
# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Obtener las radio de los exoplanetas y la densidad de la Tierra
radios_exoplanetas = dFFinal2505['pl_rade']  # Reemplaza "df['densidades']" con la columna que contiene las densidades de tus exoplanetas
radio_tierra = 1  # radio de la Tierra

# Crear una lista de valores de 0 para el eje y
radio_tierra_comparativa = [radio_tierra] * len(radios_exoplanetas)

# Crear una lista de tamaños para las burbujas
sizes = [100] * len(radios_exoplanetas)  # Puedes ajustar el tamaño de las burbujas según tus preferencias

# Crear una lista de colores para las burbujas
colors = ['blue'] * len(radios_exoplanetas)  # Puedes ajustar el color de las burbujas según tus preferencias

# Graficar las densidades comparativas en un gráfico de burbujas
plt.scatter(range(len(radios_exoplanetas)), radio_tierra_comparativa, s=sizes, c='gold', alpha=0.5, label='Earth radius')
plt.scatter(range(len(radios_exoplanetas)), radios_exoplanetas, s=sizes, c='mediumorchid', alpha=0.5, label='Exoplanet radius')

# Etiquetas y título del gráfico
plt.xlabel('Exoplanet Index')
plt.ylabel('Radius times earth')


# Ajustar los límites de los ejes para el acercamiento
plt.xlim(-5, len(radios_exoplanetas) + 5)  # Ajusta los valores -5 y +5 según la zona que deseas mostrar en el eje x
plt.ylim(-0.5, 5)  # Ajusta los valores -0.5 y 2 según la zona que deseas mostrar en el eje y

# Leyenda
plt.legend()
plt.savefig('grafica_radios.png')
# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Obtener las tempEff de los exoplanetas y la densidad de la Tierra
starTemp = dFFinal2505['st_teff'] 
sunTemp = 5777 # radio de la Tierra

# Crear una lista de valores de 0 para el eje y
sun_comparativa = [sunTemp] * len(starTemp)

# Crear una lista de tamaños para las burbujas
sizes = [100] * len(starTemp)  # Puedes ajustar el tamaño de las burbujas según tus preferencias

# Crear una lista de colores para las burbujas
colors = ['blue'] * len(starTemp)  # Puedes ajustar el color de las burbujas según tus preferencias

# Graficar las densidades comparativas en un gráfico de burbujas
plt.scatter(range(len(starTemp)), sun_comparativa, s=sizes, c='gold', alpha=0.5, label='Sun effective temperature [K]')
plt.scatter(range(len(starTemp)), starTemp, s=sizes, c='mediumorchid', alpha=0.5, label='Exoplanet star effective temperature [K]')

# Etiquetas y título del gráfico
plt.xlabel('Exoplanet Index')
plt.ylabel('Exoplanet star effective temperature')


# Ajustar los límites de los ejes para el acercamiento
plt.xlim(-15, len(starTemp) + 15)  # Ajusta los valores -5 y +5 según la zona que deseas mostrar en el eje x
plt.ylim(-15, 9000)  # Ajusta los valores -0.5 y 2 según la zona que deseas mostrar en el eje y

# Leyenda
plt.legend()
plt.savefig('grafica_tempEff.png')
# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Obtener las tempEff de los exoplanetas y la densidad de la Tierra
exoTempeq = dFFinal2505['pl_eqt'] 
earthTempeq = 255 # Earth Equilibrium Temperature [K]

# Crear una lista de valores de 0 para el eje y
EqTemp_comparativa = [earthTempeq] * len(exoTempeq)

# Crear una lista de tamaños para las burbujas
sizes = [100] * len(exoTempeq)  # Puedes ajustar el tamaño de las burbujas según tus preferencias

# Crear una lista de colores para las burbujas
colors = ['blue'] * len(exoTempeq)  # Puedes ajustar el color de las burbujas según tus preferencias

# Graficar las densidades comparativas en un gráfico de burbujas
plt.scatter(range(len(exoTempeq)), EqTemp_comparativa, s=sizes, c='gold', alpha=0.5, label='Earth Equilibrium Temperature [K]')
plt.scatter(range(len(exoTempeq)), exoTempeq, s=sizes, c='mediumorchid', alpha=0.5, label='Exoplanet Equilibrium Temperature [K]')

# Etiquetas y título del gráfico
plt.xlabel('Exoplanet Index')
plt.ylabel('Exoplanet Equilibrium Temperature [K]')


# Ajustar los límites de los ejes para el acercamiento
plt.xlim(-15, len(exoTempeq) + 15)  # Ajusta los valores -5 y +5 según la zona que deseas mostrar en el eje x
plt.ylim(-100, 2500)  # Ajusta los valores -0.5 y 2 según la zona que deseas mostrar en el eje y

# Leyenda
plt.legend()
plt.savefig('grafica_ExoEqTemp.png')
# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Asignación de pesos a cada variable

# %%
import matplotlib.pyplot as plt

# Obtener las tempEff de los exoplanetas y la densidad de la Tierra
exoTempeq = dFFinal2505['pl_eqt'] 
earthTempeq = 255 # Earth Equilibrium Temperature [K]
# Crear el mosaico de gráficas
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
# Crear una lista de valores de 0 para el eje y
EqTemp_comparativa = [earthTempeq] * len(exoTempeq)
# Crear una lista de tamaños para las burbujas
sizes = [100] * len(exoTempeq)  # Puedes ajustar el tamaño de las burbujas según tus preferencias
#=========================================================================================================
# Obtener las densidades de los exoplanetas y la densidad de la Tierra
densidades_exoplanetas = dFFinal2505['dens_pl_ert']  # Reemplaza "df['densidades']" con la columna que contiene las densidades de tus exoplanetas
densidad_tierra = 1  # Densidad de la Tierra
# Crear una lista de valores de 0 para el eje y
densidad_tierra_comparativa = [densidad_tierra] * len(densidades_exoplanetas)
#===========================================================================================================
# Obtener las radio de los exoplanetas y la densidad de la Tierra
radios_exoplanetas = dFFinal2505['pl_rade']  # Reemplaza "df['densidades']" con la columna que contiene las densidades de tus exoplanetas
radio_tierra = 1  # radio de la Tierra
# Crear una lista de valores de 0 para el eje y
radio_tierra_comparativa = [radio_tierra] * len(radios_exoplanetas)
# Crear una lista de tamaños para las burbujas
sizes = [100] * len(radios_exoplanetas) 
#===========================================================================================================
# Obtener las tempEff de los exoplanetas y la densidad de la Tierra
starTemp = dFFinal2505['st_teff'] 
sunTemp = 5777 # radio de la Tierra
# Crear una lista de valores de 0 para el eje y
sun_comparativa = [sunTemp] * len(starTemp)
# Crear una lista de tamaños para las burbujas
sizes = [100] * len(starTemp) 
#===========================================================================================================
# Crear una lista de tamaños para las burbujas
sizes = [100] * len(densidades_exoplanetas)
# Crear una lista de colores para las burbujas
colors = ['blue'] * len(exoTempeq)  # Puedes ajustar el color de las burbujas según tus preferencias
#===========================================================================================================
# Graficar las densidades comparativas en un gráfico de burbujas
axs[0, 0].scatter(range(len(exoTempeq)), EqTemp_comparativa, s=sizes, c='gold', alpha=0.5, label='Earth Equilibrium Temperature [K]')
axs[0, 0].scatter(range(len(exoTempeq)), exoTempeq, s=sizes, c='mediumorchid', alpha=0.5, label='Exoplanet Equilibrium Temperature [K]')
# Etiquetas y título del gráfico
axs[0, 0].set_xlabel('Exoplanet Index')
axs[0, 0].set_ylabel('Exoplanet Equilibrium Temperature [K]')
# Ajustar los límites de los ejes para el acercamiento
axs[0, 0].set_xlim(-15, len(exoTempeq) + 15) # Ajusta los valores -5 y +5 según la zona que deseas mostrar en el eje x
axs[0, 0].set_ylim(-100, 2500)  # Ajusta los valores -0.5 y 2 según la zona que deseas mostrar en el eje y
# Leyenda
axs[0, 0].legend('Equilibrium Temperature [K] comparison')
#===========================================================================================================
#Segundo grafico
# Graficar las densidades comparativas en un gráfico de burbujas
axs[0, 1].scatter(range(len(densidades_exoplanetas)), densidad_tierra_comparativa, s=sizes, c='gold', alpha=0.5, label='Earth density')
axs[0, 1].scatter(range(len(densidades_exoplanetas)), densidades_exoplanetas, s=sizes, c='mediumorchid', alpha=0.5, label='Exoplanet density')
# Etiquetas y título del gráfico
axs[0, 1].set_xlabel('Exoplanet Index')
axs[0, 1].set_ylabel('Density times earth')
# Ajustar los límites de los ejes para el acercamiento
axs[0, 1].set_xlim(-5, len(densidades_exoplanetas) + 5) # Ajusta los valores -5 y +5 según la zona que deseas mostrar en el eje x
axs[0, 1].set_ylim(-0.5, 2)  # Ajusta los valores -0.5 y 2 según la zona que deseas mostrar en el eje y
# Leyenda
axs[0, 1].legend('Density comparison')
#===========================================================================================================
# Graficar las densidades comparativas en un gráfico de burbujas
axs[1, 0].scatter(range(len(starTemp)), sun_comparativa, s=sizes, c='gold', alpha=0.5, label='Sun effective temperature [K]')
axs[1, 0].scatter(range(len(starTemp)), starTemp, s=sizes, c='mediumorchid', alpha=0.5, label='Exoplanet star effective temperature [K]')
# Etiquetas y título del gráfico
axs[1, 0].set_xlabel('Exoplanet Index')
axs[1, 0].set_ylabel('Exoplanet star effective temperature')
# Ajustar los límites de los ejes para el acercamiento
axs[1, 0].set_xlim(-15, len(starTemp) + 15) # Ajusta los valores -5 y +5 según la zona que deseas mostrar en el eje x
axs[1, 0].set_ylim(-15, 9000)  # Ajusta los valores -0.5 y 2 según la zona que deseas mostrar en el eje y
# Leyenda
axs[1, 0].legend('Effective temperature comparison')
#===========================================================================================================
# Graficar las densidades comparativas en un gráfico de burbujas
axs[1, 1].scatter(range(len(radios_exoplanetas)), radio_tierra_comparativa, s=sizes, c='gold', alpha=0.5, label='Earth radius')
axs[1, 1].scatter(range(len(radios_exoplanetas)), radios_exoplanetas, s=sizes, c='mediumorchid', alpha=0.5, label='Exoplanet radius')
# Etiquetas y título del gráfico
axs[1, 1].set_xlabel('Exoplanet Index')
axs[1, 1].set_ylabel('Radius times earth')
# Ajustar los límites de los ejes para el acercamiento
axs[1, 1].set_xlim(-5, len(radios_exoplanetas) + 5)  # Ajusta los valores -5 y +5 según la zona que deseas mostrar en el eje x
axs[1, 1].set_ylim(-0.5, 5)
axs[1, 1].legend('Radius comparison')
#===========================================================================================================
plt.savefig('Mos_Graf_4.png')
fig.tight_layout()
# Mostrar el gráfico
plt.show()

# %% [markdown]
# En los graficos anteriores podemos notar las variables que tienen un mayor peso comparativo con respecto a la tierra es así que usaremos esto como un referente para asignarle un peso a cada una de estas variables para de esta forma poder determinar un indice de similitud.

# %%
df = pd.read_csv('RealTessDataUse.csv')
dFFinal0206 = pd.DataFrame(df)
dFFinal0206['pl_rade'] = dFFinal0206['pl_rade'].apply(lambda x: x * 6371) #km
dFFinal0206['dens_pl_ert'] = dFFinal0206['dens_pl_ert'].apply(lambda x: x * 5.51) #g/cm³
dFFinal0206
# Out:
#      Unnamed: 0    pl_rade   pl_bmasse  st_teff  pl_eqt    Pl_eh_vol  \
# 0             0  16628.310    22.70000   4640.0     422    17.779581
# 1             1  13570.230     3.34000   3556.0     693     9.663597
# 2             2   8052.944     1.86000   3347.0     773     2.019488
# 3             3   7753.507     1.84000   3505.0     525     1.802485
# 4             4   4574.378     0.54600   3522.0    1745     0.370146
# ..          ...        ...         ...      ...     ...          ...
# 207         207  76413.774   301.93850   6261.0    1397  1725.409296
# 208         208  83625.746   211.99261   5570.0    1192  2261.503164
# 209         209  60843.050    55.30242   5710.0    1526   870.983875
# 210         210  17615.815     9.10000   4435.0     941    21.139047
# 211         211  66258.400  4386.05400   4710.0     163  1124.864000
#
#      dens_pl_ert
# 0       7.034888
# 1       1.904410
# 2       5.074866
# 3       5.624694
# 4       8.127784
# ..           ...
# ...

# %% [markdown]
# # Calculando los pesos de que tendrá cada variable
# ![pesoscalculo.PNG](attachment:pesoscalculo.PNG)
#
# Siendo V = 0.8

# %%
dFFinal0206
# Out:
#      Unnamed: 0    pl_rade   pl_bmasse  st_teff  pl_eqt    Pl_eh_vol  \
# 0             0  16628.310    22.70000   4640.0     422    17.779581
# 1             1  13570.230     3.34000   3556.0     693     9.663597
# 2             2   8052.944     1.86000   3347.0     773     2.019488
# 3             3   7753.507     1.84000   3505.0     525     1.802485
# 4             4   4574.378     0.54600   3522.0    1745     0.370146
# ..          ...        ...         ...      ...     ...          ...
# 207         207  76413.774   301.93850   6261.0    1397  1725.409296
# 208         208  83625.746   211.99261   5570.0    1192  2261.503164
# 209         209  60843.050    55.30242   5710.0    1526   870.983875
# 210         210  17615.815     9.10000   4435.0     941    21.139047
# 211         211  66258.400  4386.05400   4710.0     163  1124.864000
#
#      dens_pl_ert
# 0       7.034888
# 1       1.904410
# 2       5.074866
# 3       5.624694
# 4       8.127784
# ..           ...
# ...

# %% [markdown]
# Wr = 3.2
#
# Wd = 1.07
#
# Wteff = 0.81
#
# Weqt = 1.29

# %%
def esi_valor(valor):
    return ((1-((valor-6371)/(valor+6371)))**3.2)

dFFinal0206['esi_rad'] = dFFinal0206['pl_rade'].apply(esi_valor)

# %%
dFFinal0206
# Out:
#      Unnamed: 0    pl_rade   pl_bmasse  st_teff  pl_eqt    Pl_eh_vol  \
# 0             0  16628.310    22.70000   4640.0     422    17.779581
# 1             1  13570.230     3.34000   3556.0     693     9.663597
# 2             2   8052.944     1.86000   3347.0     773     2.019488
# 3             3   7753.507     1.84000   3505.0     525     1.802485
# 4             4   4574.378     0.54600   3522.0    1745     0.370146
# ..          ...        ...         ...      ...     ...          ...
# 207         207  76413.774   301.93850   6261.0    1397  1725.409296
# 208         208  83625.746   211.99261   5570.0    1192  2261.503164
# 209         209  60843.050    55.30242   5710.0    1526   870.983875
# 210         210  17615.815     9.10000   4435.0     941    21.139047
# 211         211  66258.400  4386.05400   4710.0     163  1124.864000
#
#      dens_pl_ert   esi_rad
# 0       7.034888  0.151103
# 1       1.904410  0.238536
# 2       5.074866  0.672499
# ...

# %%
def esi_valor(valor):
    return ((1-((valor-5.51)/(valor+5.51)))**1.07)

dFFinal0206['esi_dens'] = dFFinal0206['dens_pl_ert'].apply(esi_valor)

# %%
dFFinal0206
# Out:
#      Unnamed: 0    pl_rade   pl_bmasse  st_teff  pl_eqt    Pl_eh_vol  \
# 0             0  16628.310    22.70000   4640.0     422    17.779581
# 1             1  13570.230     3.34000   3556.0     693     9.663597
# 2             2   8052.944     1.86000   3347.0     773     2.019488
# 3             3   7753.507     1.84000   3505.0     525     1.802485
# 4             4   4574.378     0.54600   3522.0    1745     0.370146
# ..          ...        ...         ...      ...     ...          ...
# 207         207  76413.774   301.93850   6261.0    1397  1725.409296
# 208         208  83625.746   211.99261   5570.0    1192  2261.503164
# 209         209  60843.050    55.30242   5710.0    1526   870.983875
# 210         210  17615.815     9.10000   4435.0     941    21.139047
# 211         211  66258.400  4386.05400   4710.0     163  1124.864000
#
#      dens_pl_ert   esi_rad  esi_dens
# 0       7.034888  0.151103  0.870512
# 1       1.904410  0.238536  1.528102
# ...

# %%
def esi_valor(valor):
    return ((1-((valor-5777)/(valor+5777)))**0.81)

dFFinal0206['esi_stteff'] = dFFinal0206['st_teff'].apply(esi_valor)

# %%
dFFinal0206
# Out:
#      Unnamed: 0    pl_rade   pl_bmasse  st_teff  pl_eqt    Pl_eh_vol  \
# 0             0  16628.310    22.70000   4640.0     422    17.779581
# 1             1  13570.230     3.34000   3556.0     693     9.663597
# 2             2   8052.944     1.86000   3347.0     773     2.019488
# 3             3   7753.507     1.84000   3505.0     525     1.802485
# 4             4   4574.378     0.54600   3522.0    1745     0.370146
# ..          ...        ...         ...      ...     ...          ...
# 207         207  76413.774   301.93850   6261.0    1397  1725.409296
# 208         208  83625.746   211.99261   5570.0    1192  2261.503164
# 209         209  60843.050    55.30242   5710.0    1526   870.983875
# 210         210  17615.815     9.10000   4435.0     941    21.139047
# 211         211  66258.400  4386.05400   4710.0     163  1124.864000
#
#      dens_pl_ert   esi_rad  esi_dens  esi_stteff
# 0       7.034888  0.151103  0.870512    1.087531
# ...

# %%
def esi_valor(valor):
    return ((1-((valor-255)/(valor+255)))**1.29)

dFFinal0206['esi_eqt'] = dFFinal0206['pl_eqt'].apply(esi_valor)

# %%
dFFinal0206
# Out:
#      Unnamed: 0    pl_rade   pl_bmasse  st_teff  pl_eqt    Pl_eh_vol  \
# 0             0  16628.310    22.70000   4640.0     422    17.779581
# 1             1  13570.230     3.34000   3556.0     693     9.663597
# 2             2   8052.944     1.86000   3347.0     773     2.019488
# 3             3   7753.507     1.84000   3505.0     525     1.802485
# 4             4   4574.378     0.54600   3522.0    1745     0.370146
# ..          ...        ...         ...      ...     ...          ...
# 207         207  76413.774   301.93850   6261.0    1397  1725.409296
# 208         208  83625.746   211.99261   5570.0    1192  2261.503164
# 209         209  60843.050    55.30242   5710.0    1526   870.983875
# 210         210  17615.815     9.10000   4435.0     941    21.139047
# 211         211  66258.400  4386.05400   4710.0     163  1124.864000
#
#      dens_pl_ert   esi_rad  esi_dens  esi_stteff   esi_eqt
# 0       7.034888  0.151103  0.870512    1.087531  0.693915
# ...

# %%
dFFinal0206['Esi_i'] = np.sqrt(dFFinal0206['esi_dens'] * dFFinal0206['esi_rad'])

# %%
dFFinal0206
# Out:
#      Unnamed: 0    pl_rade   pl_bmasse  st_teff  pl_eqt    Pl_eh_vol  \
# 0             0  16628.310    22.70000   4640.0     422    17.779581
# 1             1  13570.230     3.34000   3556.0     693     9.663597
# 2             2   8052.944     1.86000   3347.0     773     2.019488
# 3             3   7753.507     1.84000   3505.0     525     1.802485
# 4             4   4574.378     0.54600   3522.0    1745     0.370146
# ..          ...        ...         ...      ...     ...          ...
# 207         207  76413.774   301.93850   6261.0    1397  1725.409296
# 208         208  83625.746   211.99261   5570.0    1192  2261.503164
# 209         209  60843.050    55.30242   5710.0    1526   870.983875
# 210         210  17615.815     9.10000   4435.0     941    21.139047
# 211         211  66258.400  4386.05400   4710.0     163  1124.864000
#
#      dens_pl_ert   esi_rad  esi_dens  esi_stteff   esi_eqt     Esi_i
# 0       7.034888  0.151103  0.870512    1.087531  0.693915  0.362680
# ...

# %%
dFFinal0206['Esi_s'] = np.sqrt(dFFinal0206['esi_stteff'] * dFFinal0206['esi_eqt'])

# %%
dFFinal0206
# Out:
#      Unnamed: 0    pl_rade   pl_bmasse  st_teff  pl_eqt    Pl_eh_vol  \
# 0             0  16628.310    22.70000   4640.0     422    17.779581
# 1             1  13570.230     3.34000   3556.0     693     9.663597
# 2             2   8052.944     1.86000   3347.0     773     2.019488
# 3             3   7753.507     1.84000   3505.0     525     1.802485
# 4             4   4574.378     0.54600   3522.0    1745     0.370146
# ..          ...        ...         ...      ...     ...          ...
# 207         207  76413.774   301.93850   6261.0    1397  1725.409296
# 208         208  83625.746   211.99261   5570.0    1192  2261.503164
# 209         209  60843.050    55.30242   5710.0    1526   870.983875
# 210         210  17615.815     9.10000   4435.0     941    21.139047
# 211         211  66258.400  4386.05400   4710.0     163  1124.864000
#
#      dens_pl_ert   esi_rad  esi_dens  esi_stteff   esi_eqt     Esi_i     Esi_s
# ...

# %%
dFFinal0206['Esi_value'] = np.sqrt(dFFinal0206['Esi_i'] * dFFinal0206['Esi_s'])

# %%
dFFinal0206.to_csv('FINAL_FINAL_ESI_DATA.csv')
dFFinal0206
# Out:
#      Unnamed: 0    pl_rade   pl_bmasse  st_teff  pl_eqt    Pl_eh_vol  \
# 0             0  16628.310    22.70000   4640.0     422    17.779581
# 1             1  13570.230     3.34000   3556.0     693     9.663597
# 2             2   8052.944     1.86000   3347.0     773     2.019488
# 3             3   7753.507     1.84000   3505.0     525     1.802485
# 4             4   4574.378     0.54600   3522.0    1745     0.370146
# ..          ...        ...         ...      ...     ...          ...
# 207         207  76413.774   301.93850   6261.0    1397  1725.409296
# 208         208  83625.746   211.99261   5570.0    1192  2261.503164
# 209         209  60843.050    55.30242   5710.0    1526   870.983875
# 210         210  17615.815     9.10000   4435.0     941    21.139047
# 211         211  66258.400  4386.05400   4710.0     163  1124.864000
#
#      dens_pl_ert   esi_rad  esi_dens  esi_stteff   esi_eqt     Esi_i  \
# ...

# %%
dFFinal0206byesi = dFFinal0206.sort_values('Esi_value')
dFFinal0206byesi
# Out:
#      Unnamed: 0     pl_rade   pl_bmasse  st_teff  pl_eqt     Pl_eh_vol  \
# 123         123   96189.358  1595.49860   6540.0    3646   3441.583121
# 157         157  149966.969   375.03752   5810.0    1498  13042.595540
# 39           39  144965.734  1021.18779   4590.0    1411  11780.758720
# 88           88  106402.071   991.62463   7690.0    2370   4658.299720
# 196         196  126470.721   279.69040   6460.0    1749   7822.528752
# ..          ...         ...         ...      ...     ...           ...
# 23           23    5211.478     0.72000   4684.0     723      0.547343
# 79           79    9938.760     2.20000   3600.0     344      3.796416
# 51           51    7307.537     1.54000   3340.0     508      1.509004
# 24           24    7243.827     0.77000   4684.0     630      1.469878
# 43           43    5415.350     0.40000   3415.0     627      0.614125
#
#      dens_pl_ert   esi_rad  esi_dens  esi_stteff   esi_eqt     Esi_i  \
# ...

# %%
dfShow=dFFinal0206byesi[['pl_rade','dens_pl_ert','Esi_value']]
dfShow
# Out:
#         pl_rade  dens_pl_ert  Esi_value
# 123   96189.358     2.554412   0.104977
# 157  149966.969     0.158440   0.107893
# 39   144965.734     0.477623   0.113459
# 88   106402.071     1.172932   0.114177
# 196  126470.721     0.197008   0.116210
# ..          ...          ...        ...
# 23     5211.478     7.248121   0.858383
# 79     9938.760     3.193021   0.865935
# 51     7307.537     5.623197   0.868124
# 24     7243.827     2.886438   0.871185
# 43     5415.350     3.588856   0.983404
#
# [212 rows x 3 columns]

# %% [markdown]
# # Ahora ya tenemos el valor ESI de cada exoplaneta este valor indica segun sus autores que todo planeta con un valor ESI igual o mayor a 0.8 es altamente similar a la tierra

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


# Datos de entrenamiento
densidades_planetas = dFFinal0206byesi['dens_pl_ert']
radios_planetas = dFFinal0206byesi['pl_rade']
temperaturas_estrella = dFFinal0206byesi['st_teff']
equilibrio_temperatura = dFFinal0206byesi['pl_eqt']
Esival = dFFinal0206byesi['Esi_value']

# Preprocesamiento de datos
X = list(zip(densidades_planetas, radios_planetas, temperaturas_estrella, equilibrio_temperatura))
y = Esival

# División de datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=52)

# Creación y entrenamiento del modelo KNN Regressor
k = 4  # Número de vecinos a considerar
knn = KNeighborsRegressor(n_neighbors=k)
knn.fit(X_train, y_train)

# Predicción en el conjunto de prueba
y_pred = knn.predict(X_test)

# Evaluación del modelo
mse = mean_squared_error(y_test, y_pred)
print(f"Error cuadrático medio: {mse}")

# Predicción para un nuevo planeta
# [Densidad, Radio, Temperatura Estrella, Equilibrio de Temperatura]
nuevo_planeta = [[5.5, 3500, 5777, 250]]  # Ejemplo de nuevos valores de densidad, radio, temperatura estrella y equilibrio de temperatura
similitud = knn.predict(nuevo_planeta)
print(f"La similitud del nuevo planeta con la Tierra es: {similitud}")
# Out:
# Error cuadrático medio: 0.0065029587533228
# La similitud del nuevo planeta con la Tierra es: [0.83082485]

# %%
import matplotlib.pyplot as plt

# Crear la figura y las subtramas
fig, ax = plt.subplots()

# Graficar el colormap en el fondo
cmap = ax.scatter(y_test, y_pred, c=y_test, cmap='spring', alpha=0.3)

# Graficar los puntos principales en primer plano
scatter = ax.scatter(y_test, y_pred, c=y_pred, cmap='spring', edgecolors='black')

# Configurar el gráfico




# Agregar el colormap en la barra lateral
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Earth Similitude')

plt.savefig('simil.png')
plt.show()

# %%
df = pd.read_csv('exoplanetList.CSV')
exoplList = pd.DataFrame(df)

exoplList
# Out:
#     Unnamed: 0        Planet  Period  pl_bmasse    pl_rade  pl_eqt  st_teff  \
# 0            0      L98-59 d    7.45       1.94   9690.291     416  3367.00
# 1            1  Kepler 138 c   13.78       2.30   9620.210     410  3726.00
# 2            2   HD 260655 c    5.71       3.09   9766.743     557  3803.00
# 3            3    HD 23472 c   29.80       3.41  11913.770     467  4826.33
# 4            4     TOI-776 b    8.25       4.00  11786.350     514  4002.00
# 5            5       G9-40 b    5.75       4.00  12104.900     441  3708.00
# 6            6     TOI-270 d   11.38       4.78  13589.343     387  3886.16
# 7            7    TOI-1452 b   11.06       4.82  10652.312     326  3185.00
# 8            8      K2-146 b    2.64       5.77  13060.550     534  3385.00
# 9            9    TOI-1468 c   15.53       6.64  13124.260     338  3382.00
# 10          10      K2-146 c    4.00       7.49  13952.490     534  3385.00
# ...

# %%
X_nuevo = list(zip(exoplList['dens_pl_ert'], exoplList['pl_rade'], exoplList['st_teff'], exoplList['pl_eqt']))
predicciones_nuevo = knn.predict(X_nuevo)
print("Predicciones para el nuevo DataFrame:")
for prediccion in predicciones_nuevo:
    print(prediccion)
# Out:
# Predicciones para el nuevo DataFrame:
# 0.8176754020067425
# 0.7750069027949326
# 0.7750069027949326
# 0.6812693188128014
# 0.6835007041290467
# 0.7052836922265011
# 0.6676150372128382
# 0.7310326848248894
# 0.6711965364795044
# 0.6711965364795044
# 0.657579078056843
# 0.6626371072676277
# 0.657579078056843
# 0.5535882798649076
# 0.5662249626980158

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import learning_curve

# Datos de entrenamiento
densidades_planetas = dFFinal0206byesi['dens_pl_ert']
radios_planetas = dFFinal0206byesi['pl_rade']
temperaturas_estrella = dFFinal0206byesi['st_teff']
equilibrio_temperatura = dFFinal0206byesi['pl_eqt']
Esival = dFFinal0206byesi['Esi_value']

# Preprocesamiento de datos
X = list(zip(densidades_planetas, radios_planetas, temperaturas_estrella, equilibrio_temperatura))
y = Esival

# División de datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=52)

# Creación y entrenamiento del modelo KNN Regressor
k = 4  # Número de vecinos a considerar
knn = KNeighborsRegressor(n_neighbors=k)

# Generación de la curva de aprendizaje
train_sizes, train_scores, test_scores = learning_curve(
    knn, X_train, y_train, cv=5, scoring='neg_mean_squared_error', 
    train_sizes=np.linspace(0.1, 1.0, 10)
)

# Cálculo del error cuadrático medio promedio en cada conjunto de entrenamiento
train_mse = -np.mean(train_scores, axis=1)
test_mse = -np.mean(test_scores, axis=1)

# Graficar la curva de aprendizaje
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mse, 'o-', color='r', label='Entrenamiento')
plt.plot(train_sizes, test_mse, 'o-', color='g', label='Prueba')
plt.xlabel('Tamaño del conjunto de entrenamiento')
plt.ylabel('Error cuadrático medio')
plt.title('Curva de Aprendizaje')
plt.legend(loc='best')
plt.savefig('apr4.png')
plt.show()

# Entrenamiento final con todo el conjunto de entrenamiento
knn.fit(X_train, y_train)

# Predicción en el conjunto de prueba
y_pred = knn.predict(X_test)

# Evaluación del modelo
mse = mean_squared_error(y_test, y_pred)
print(f"Error cuadrático medio: {mse}")

# Predicción para un nuevo planeta
# [Densidad, Radio, Temperatura Estrella, Equilibrio de Temperatura]
nuevo_planeta = [[5, 3000, 5000, 300]]  # Ejemplo de nuevos valores de densidad, radio, temperatura estrella y equilibrio de temperatura
similitud = knn.predict(nuevo_planeta)
print(f"La similitud del nuevo planeta con la Tierra es: {similitud}")
# Out:
# Error cuadrático medio: 0.0064937561100814525
# La similitud del nuevo planeta con la Tierra es: [0.83082485]

# %%
X_nuevo = list(zip(dFFinal0206byesi['dens_pl_ert'], dFFinal0206byesi['pl_rade'], dFFinal0206byesi['st_teff'], dFFinal0206byesi['pl_eqt']))
predicciones_nuevo = knn.predict(X_nuevo)
print("Predicciones para el nuevo DataFrame:")
for prediccion in predicciones_nuevo:
    print(prediccion)
# Out:
# Predicciones para el nuevo DataFrame:
# 0.13269079433556888
# 0.11567010902621137
# 0.11567010902621137
# 0.13426362728356073
# 0.11904412230972956
# 0.11904412230972956
# 0.13020601321055475
# 0.13020601321055478
# 0.12627600069003775
# 0.15814772104063957
# 0.1342891476437634
# 0.13426362728356073
# 0.1342891476437634
# 0.13702776412886666
# 0.14458990796398874
# 0.14936559426460394
# 0.1342891476437634
# 0.15447282764268414
# 0.1356148200789894
# 0.16114848224134656
# 0.1345187744872337
# 0.14936559426460394
# 0.15961172272754637
# 0.14936559426460394
# 0.14841450572015166
# 0.13269079433556888
# 0.15447282764268414
# 0.16077594143785442
# 0.17010124190842618
# 0.14936559426460394
# 0.14458990796398874
# 0.16395085946828541
# 0.16395085946828541
# 0.16585543800518934
# 0.15447282764268414
# 0.19539798311789974
# 0.17093021789362392
# 0.16077594143785442
# 0.16389697446031057
# 0.17589373928038327
# 0.2029591523326883
# 0.16395742654858578
# 0.16936678628871774
# ...

# %%
dFFinal0206byesi.to_csv('TestDataKNR.csv')
dFFinal0206byesi
# Out:
#      Unnamed: 0     pl_rade   pl_bmasse  st_teff  pl_eqt     Pl_eh_vol  \
# 123         123   96189.358  1595.49860   6540.0    3646   3441.583121
# 157         157  149966.969   375.03752   5810.0    1498  13042.595540
# 39           39  144965.734  1021.18779   4590.0    1411  11780.758720
# 88           88  106402.071   991.62463   7690.0    2370   4658.299720
# 196         196  126470.721   279.69040   6460.0    1749   7822.528752
# ..          ...         ...         ...      ...     ...           ...
# 23           23    5211.478     0.72000   4684.0     723      0.547343
# 79           79    9938.760     2.20000   3600.0     344      3.796416
# 51           51    7307.537     1.54000   3340.0     508      1.509004
# 24           24    7243.827     0.77000   4684.0     630      1.469878
# 43           43    5415.350     0.40000   3415.0     627      0.614125
#
#      dens_pl_ert   esi_rad  esi_dens  esi_stteff   esi_eqt     Esi_i  \
# ...
